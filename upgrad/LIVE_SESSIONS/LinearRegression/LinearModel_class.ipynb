# %% [markdown]
# 1. What is linear Regression
# 2. How it works(mathematics)
# 3. Model Evaluation techniques/methods
#     - Residual analysis
#     - Root mean squqre Error (RMSE)
#     - r-square score
# 4. Deal with non-linear model with linear regression

# %% [markdown]
# 1. Supervised learning we have both X and y - both input and o/p
# 2. Predict y in future

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# source - http://digitalfirst.bfwpub.com/stats_applet/stats_applet_5_correg.html

# %% [markdown]
# 1. calculate - mean x and mean y
# 2. Calculate residue
# 3. OLS method - Ordinary Least Square method - minimize the residue
# 4. Change angle of line to reduce the residue

# %%
import numpy as np
import pandas as pd

# %%
x=[1,2,3,4,5,6,7]
y=[1,4,9,16,24,36,49]

# %%
dict = {"area": x, "price": y}
df = pd.DataFrame(dict)
df
# Out:
#    area  price
# 0     1      1
# 1     2      4
# 2     3      9
# 3     4     16
# 4     5     24
# 5     6     36
# 6     7     49

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
