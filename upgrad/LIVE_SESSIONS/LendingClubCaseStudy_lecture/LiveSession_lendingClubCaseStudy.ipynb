# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
missingno - library for analyzing null values

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Graphs - Crosstab
violin

# %% [markdown]
# ![image.png](attachment:image.png)
