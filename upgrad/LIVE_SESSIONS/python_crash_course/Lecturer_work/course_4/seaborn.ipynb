# %% [markdown]
# This kernel aims at depicting various plots and visualization techniques which can be done using seaborn library.It covers the basic to advance level plotting functions of the libraray.It contains several examples which will give you hands-on experience in generating plots in python.

# %% [markdown]
# # **1.Introduction to Seaborn**
#
# Seaborn provides a high-level interface to Matplotlib, a powerful but sometimes unwieldy Python visualization library.On Seaborn’s official website, they state:
#
# > If matplotlib “tries to make easy things easy and hard things possible”, seaborn tries to make a well-defined set of hard things easy too.
#
# Features of Seaborn :
#
# * Using default themes that are aesthetically pleasing.
# * Setting custom color palettes.
# * Making attractive statistical plots.
# * Easily and flexibly displaying distributions.
# * Visualizing information from matrices and DataFrames.
#
# Those last three points are why **Seaborn is our tool of choice for Exploratory Analysis**. It makes it very easy to “get to know” your data quickly and efficiently.

# %% [markdown]
# # **2.Seaborn vs Matplotlib**
#
# It is summarized that if Matplotlib “tries to make easy things easy and hard things possible”, Seaborn tries to make a well-defined set of hard things easy too.”
#
# Seaborn helps resolve the two major problems faced by Matplotlib; the problems are −
#
# * Default Matplotlib parameters
# * Working with data frames
#
# As Seaborn compliments and extends Matplotlib, the learning curve is quite gradual. If you know Matplotlib, you are already half way through Seaborn.

# %% [markdown]
# # 3.Import libraries <a class="anchor" id="3"></a>
#
# [Table of Contents](#0.1)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# # **4. Line Charts**

# %%
col1 = np.linspace(0, 10, 1000)
col2 = np.sin(col1)
df = pd.DataFrame({"C1" : col1 , "C2" :col2})
df.head(10)
# Out:
#         C1        C2
# 0  0.00000  0.000000
# 1  0.01001  0.010010
# 2  0.02002  0.020019
# 3  0.03003  0.030026
# 4  0.04004  0.040029
# 5  0.05005  0.050029
# 6  0.06006  0.060024
# 7  0.07007  0.070013
# 8  0.08008  0.079995
# 9  0.09009  0.089968

# %%
# Plotting lineplot using sns.lineplot()
plt.style.use('seaborn-darkgrid')
sns.lineplot(x=df.C1,y=df.C2,data=df)
plt.show()

# %%
""" - Adjusting background color using axes.facecolor
- Changing label size using xtick.labelsize , ytick.labelsize """
plt.figure(figsize=(14,6))
sns.set(rc={'axes.facecolor':'cornflowerblue',"axes.grid":True,'xtick.labelsize':14,'ytick.labelsize':14})
sns.lineplot(x=df.C1,y=df.C2,data=df , linewidth = 2.5, color='red')
sns.lineplot(x=df.C1,y=df.C2+1,data=df , linewidth = 2.5, color='yellow')
plt.show()

# %%
""" - Adjusting background color using axes.facecolor
- Changing label size using xtick.labelsize , ytick.labelsize """
plt.figure(figsize=(14,6))
sns.set(rc={"axes.facecolor":"#283747", "axes.grid":False,'xtick.labelsize':14,'ytick.labelsize':14})
sns.lineplot(x=df.C1,y=df.C2,data=df , color = "#FF5722" , linewidth = 2 )
sns.lineplot(x=df.C1,y=np.cos(df.C1),data=df , color = "#FFEB3B" , linewidth = 2)
plt.show()

# %%
auto = pd.read_csv('./data/Automobile_data.csv')

# %%
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
plt.figure(figsize=(12,8))
plt.style.use('seaborn-darkgrid')
sns.scatterplot(x='engine-size', y='wheel-base', data = auto, color="#FF0000", marker='<')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.style.use('seaborn-darkgrid')
sns.scatterplot(x='engine-size', y='wheel-base', hue='fuel-type', data = auto, color="#FF0000", marker='<')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.style.use('seaborn-darkgrid')
sns.scatterplot(x='engine-size', y='wheel-base', hue='fuel-type',size='city-mpg', sizes=(50,250), data = auto, color="#FF0000", marker='<')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.style.use('seaborn-darkgrid')
sns.scatterplot(x='engine-size', y='wheel-base', hue='fuel-type',size='city-mpg', sizes=(50,250), alpha=0.5, data = auto, color="#FF0000", marker='<')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.distplot(auto['city-mpg'])
plt.show()
# Out:
# C:\Users\siddh\miniconda3\envs\baseml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,8))
sns.distplot(auto['city-mpg'], kde=True, hist=False)
plt.show()
# Out:
# C:\Users\siddh\miniconda3\envs\baseml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,8))
sns.distplot(auto['city-mpg'], bins=20, color="#FFF000", hist_kws=dict(edgecolor='#FF0000'))
plt.show()
# Out:
# C:\Users\siddh\miniconda3\envs\baseml\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
sns.boxplot(auto['engine-size'])
plt.show()
# Out:
# C:\Users\siddh\miniconda3\envs\baseml\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12, 8))
sns.boxplot(auto['num-of-doors'], auto['city-mpg'])
plt.show()
# Out:
# C:\Users\siddh\miniconda3\envs\baseml\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12, 8))
sns.boxplot(auto['num-of-doors'], auto['city-mpg'], order = ['four', 'two', '?'])
plt.show()
# Out:
# C:\Users\siddh\miniconda3\envs\baseml\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
auto.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(auto['num-of-doors'], auto['city-mpg'], order = ['four', 'two', '?'], hue=auto['fuel-type'], palette= {'gas': '#90EE90', 'diesel': '#33F6FF'})
plt.show()
# Out:
# C:\Users\siddh\miniconda3\envs\baseml\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(auto['num-of-doors'], auto['city-mpg'], order = ['four', 'two', '?'], hue=auto['fuel-type'], palette= {'gas': '#90EE90', 'diesel': '#33F6FF'}, width=0.5)
plt.show()
# Out:
# C:\Users\siddh\miniconda3\envs\baseml\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(auto['num-of-doors'], auto['city-mpg'], order = ['four', 'two', '?'], hue=auto['fuel-type'], palette= {'gas': '#90EE90', 'diesel': '#33F6FF'}, width=0.5, notch=True)
plt.show()
# Out:
# C:\Users\siddh\miniconda3\envs\baseml\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(auto, hue='fuel-type')

# %%
sns.pairplot(auto, hue='fuel-type', vars=['wheel-base', 'length', 'height', 'width'])

# %%
sns.pairplot(auto, hue='fuel-type', vars=['wheel-base', 'length', 'height'])

# %% [markdown]
# ### Joint Plot

# %%
mpl.rcParams.update(mpl.rcParamsDefault) #reset all seaborn and matplotlib settings

# %%
sns.jointplot(x='wheel-base', y='engine-size', data=auto, height=8)

# %%
sns.jointplot(x='wheel-base', y='engine-size', data=auto, height=8, kind='reg', ratio=2)

# %%
sns.jointplot(x='wheel-base', y='engine-size', data=auto, height=8, kind='hex', ratio=2)
