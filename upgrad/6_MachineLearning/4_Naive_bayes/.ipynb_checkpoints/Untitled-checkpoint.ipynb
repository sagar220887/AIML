# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Graded Questions

# %% [markdown]
# 1.
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5.
# What is the probability of a Deep Learning (DL) student being a male?
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Module-2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Graded Questions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.
# ![image.png](attachment:image.png)

# %% [markdown]
# 5.
# ![image.png](attachment:image.png)

# %% [markdown]
# 6.
# ![image.png](attachment:image.png)

# %% [markdown]
# 7.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Naive Bayes For Text Classification

# %% [markdown]
# ## Document Classifier - Pre Proessing Steps

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Example -

# %% [markdown]
# ### Questions

# %%
set = "A fast moving bike entered into the complex and shoot the couple"
set_no_stop_words =  "fast moving bike entered complex shoot couple"
feature_vector = 11100010

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
2.
set  ="I loved the food and cleanliness"
set_no_stop = "I loved the food and cleanliness"

# %%
0.0000020736
0.0000003528

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
3.
0.00000020736
0.00000031752

# %% [markdown]
# ![image.png](attachment:image.png)
